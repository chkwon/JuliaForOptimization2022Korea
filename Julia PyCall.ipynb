# %%
using PyCall

# %%
np = pyimport("numpy")
# Out:
# PyObject <module 'numpy' from '/usr/local/opt/python@3.9/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/numpy/__init__.py'>

# %%
np.random.rand()
# Out:
# 0.2521471339708592

# %%
a = np.random.rand(10)
# Out:
# 10-element Vector{Float64}:
#  0.07051551865886008
#  0.7830378289760574
#  0.29499298073997327
#  0.7080386584758588
#  0.6880634149182626
#  0.09525474768353337
#  0.8030239054270208
#  0.1920280511146616
#  0.4322793893732283
#  0.0643232341469967

# %%
@pyimport torch as t

# %%
t.tensor(10)
# Out:
# PyObject tensor(10)

# %%
py"""
def hello():
    print("Hello, Python!")
"""

# %%
py"hello"()
# Out:
# Hello, Python!

# %%
using PyPlot

# %%
a = rand(10)
plot(a)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 1-element Vector{PyObject}:
#  PyObject <matplotlib.lines.Line2D object at 0x14f249070>
